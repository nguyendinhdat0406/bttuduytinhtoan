# %% [markdown]
# W4A16 In các số chẵn chia hết cho 3 bé hơn 100

# %%
for i in range(101):
    if i % 3 == 0 and i % 2 == 0:
        print(i, end = " ")
# Out:
# 0 6 12 18 24 30 36 42 48 54 60 66 72 78 84 90 96

# %% [markdown]
# W4A17 Nhập vào số nguyên dương a, in ra bảng cửu chương của a

# %%
a = int(input())
for i in range(1,11):
    print(f"{a} * {i} = {a * i}")
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70

# %% [markdown]
# W4A18 Nhập vào số nguyên dương a và b, in toàn bộ ước chung của a và b

# %%
a, b = map(int, input().split())
for i in range(1, min(a, b) + 1):
    if a % i == 0 and b % i == 0:
        print(i, end = " ")
# Out:
# 1 2 3 6

# %% [markdown]
# W4A19 [EvenNumBers]
# Viết chương trình Python sử dụng một trong 2 loại vòng lặp for hoặc while để in ra các số
# dương chẵn nhỏ hơn hoặc bằng n (n <= 1000)

# %%
n = int(input())
for i in range(1,n + 1):
    if i % 2 == 0:
        print(i, end = " ")
# Out:
# 2 4

# %% [markdown]
# W4A20 Nhập vào một số nguyên dương n, kiểm tra xem n có phải là số dạng 2^k hay không

# %%
n = int(input())
k = 0
while 2**k < n:
    k += 1
if 2**k == n:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# W4A21 Nhập vào số nguyên dương n, tính tổng các chữ số của n

# %%
n = int(input())
s = 0
for i in str(n):
    s += int(i)
print(s)
# Out:
# 15

# %% [markdown]
# W4A22 Nhập vào số nguyên dương n, đếm xem n có bao nhiêu chữ số chẵn, bao nhiêu chữ số lẻ

# %%
n = int(input())
d = 0
for i in str(n):
    if int(i) % 2 == 0:
        d += 1
print(f"Có {d} chữ số chắn, {len(str(n)) - d} chữ số lẻ")
# Out:
# Có 2 chữ số chắn, 2 chữ số lẻ

# %% [markdown]
# Nhập n
# Cho S(k) = 1 + 2 + 3 + … + k
# Tìm k sao cho S(k) lớn nhất nhưng nhỏ hơn n

# %%
n = int(input())
k = 0
sk = 0
s = 0
for i in range(1, n):
    if sk + i > n:
        print(f"sk = {sk}, số k = {k}")
        break
    else:
        sk += i
        k = i
# Out:
# sk = 3, số k = 2

# %% [markdown]
# W4A24
# Nhập vào A, tìm n nhỏ nhất sao cho
# 1 + 1/2 + 1/3 + 1/4 + ... + 1/n > A

# %%
a = float(input())
s = 0
n = 1
while s <= a:
    s = s + 1/n
    n += 1
print(n, s)
# Out:
# 5 2.083333333333333

# %% [markdown]
# W4A25
# Nhập vào một dãy số nguyên, ngưng nhập khi người dùng nhập -1.
# Sau khi nhập xong, in số lớn nhất, số nhỏ nhất trong những số vừa nhập

# %%
number = []
n = 0
while n != -1:
    n = int(input())
    number.append(n)
print(max(number), min(number))
# Out:
# 9 -9

# %% [markdown]
# W4A26
# [Fibonaci1]
# Dãy số fibonacci là dãy số được định nghĩa như sau: 1, 1, 2, 3, 5, 8, 13,... với số kế tiếp sẽ
# bằng tổng hai số trước đó
# Nhập vào số nguyên dương A, hãy tìm số trong dãy số fibonacci lớn nhất nhưng không vượt
# quá A

# %%
a = int(input())
num1 = 0
num2 = 1
num = num1 + num2
while num1 + num2 <= a:
    num  = num1 + num2
    num1 = num2 
    num2 = num
print(num)
# Out:
# 5

# %% [markdown]
# W4A27
# Nhập vào một chuỗi, hãy đếm xem trong chuỗi có bao nhiêu từ (quy định là chuỗi không có
# ký tự đặc biệt, không số, không có dấu câu, chỉ có ký tự chữ và khoảng trắng)
# Dùng cách: for trên index; KHÔNG dùng hàm split(), len()

# %%
l = input()
d = 0
for i in l:
    if i != " ":
        d += 1
print(d)
# Out:
# 10

# %% [markdown]
# W4A28
# Nhập vào một chuỗi, hãy in từ đầu tiên trong chuỗi
# Dùng cách: for trên index; KHÔNG dùng hàm split()

# %%
l = input()
for i in l:
    
    if "a" <= i <="z" or "A" <= i <= "Z":
        print(i)
        break
    else:
        continue
# Out:
# v

# %% [markdown]
# W4A29
# Cho một chuỗi chỉ gồm các ký tự chữ cái thường và chữ cái hoa, hãy đổi ký tự hoa thành
# thường và thường thành hoa.

# %%
l = input()
l2 = ""
for i in l:
    if "a" <= i <= "z":
        i = i.upper()
        l2 = l2 + i
    elif "A" <= i <= "Z":
        i = i.lower()
        l2 = l2 + i
print(l2)
# Out:
# cFG

# %% [markdown]
# W4A30
# Nhập vào một chuỗi có dạng 3 số nguyên, mỗi số nguyên cách nhau một dấu phẩy, hãy tính
# tổng 3 số nguyên đó
# VD:
# Nhập: 3, 12, 15
# Tổng: 30

# %%
number = map(str, input().split(","))
s = 0
for i in number :
    s += int(i)
print(s)
# Out:
# 30

# %% [markdown]
# W4A31
# Nhập vào một chuỗi, hãy đếm xem trong chuỗi có bao nhiêu ký tự in hoa, bao nhiêu ký tự in
# thường, bao nhiêu ký tự số

# %%
l = input()
thuong = 0
hoa = 0
so = 0
for i in l:
    if "a" <= i <= "z":
        thuong += 1
    elif "A" <= i <= "Z":
        hoa += 1
    elif i.isdigit():
        so += 1
print(f"chuỗi có {thuong} kí tự in thường, {hoa} kí tự in hoa, {so} kí tự số ")
# Out:
# chuỗi có 1 kí tự in thường, 2 kí tự in hoa, 1 kí tự số
